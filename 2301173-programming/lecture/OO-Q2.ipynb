# %% [markdown]
# ## Q2
# สร้างฟังก์ชันต่อไปนี้ของคลาส ShoppingCart ในส่วนที่กำหนดให้สมบูรณ์ เพื่อให้โปรแกรมด้านล่างทำงานได้ถูกต้องตาม test cases ต่าง ๆ
# - add_item(self, item, qty) ฟังก์ชันสำหรับการเพิ่มรายการสินค้า (item) ลงในตะกร้า (cart) ด้วยจำนวนที่กำหนด (qty)
# - remove_item(self, item, qty) ฟังก์ชันสำหรับการลดรายการสินค้า (item) ในตะกร้า (cart) ด้วยจำนวนที่กำหนด (qty) ถ้าสินค้าใดมีจำนวนเป็น 0 หรือติดลบ ให้เอาสินค้านั้นออกจากตะกร้าเลย
# - get_total_qty(self) ฟังก์ชันสำหรับการคำนวณจำนวนรายการสินค้าทั้งหมด

# %% [markdown]
# ![image-2.png](./Q2.jpg)

# %%
class ShoppingCart:
    def __init__(self):
        self.cart = {}

    def add_item(self, item, qty):
        self.cart[item] = self.cart.get(item, 0) + qty

    def remove_item(self, item, qty):
        if not self.cart[item]: return
        if self.cart[item] - qty <= 0:
            del self.cart[item]
            return
        self.cart[item] = self.cart.get(item, 0) - qty

    def get_total_qty(self):
        return sum(self.cart.values())

# %%
'''ตรวจสอบผลลัพธ์'''
mycart = ShoppingCart()

mycart.add_item("Papaya", 100)
mycart.add_item("Guava", 200)
mycart.add_item("Orange", 150)

assert len(mycart.cart) == 3
assert mycart.cart['Papaya'] == 100
assert mycart.cart['Guava'] == 200
assert mycart.cart['Orange'] == 150

assert mycart.get_total_qty() == 450
print('ok')
# Out:
# ok

# %%
'''ตรวจสอบผลลัพธ์'''
mycart = ShoppingCart()

mycart.add_item("Papaya", 100)
mycart.add_item("Guava", 200)
mycart.add_item("Orange", 150)

mycart.remove_item("Orange",20)
mycart.remove_item("Papaya",200)

assert len(mycart.cart) == 2
assert mycart.cart['Guava'] == 200
assert mycart.cart['Orange'] == 130

assert mycart.get_total_qty() == 330
print('ok')
# Out:
# ok
