# %% [markdown]
# # Collection
#
# Common collections widely used in Python are
#
# 1. List
# 2. Tuple
# 3. Dict
# 4. Set

# %% [markdown]
# Again, we can use `type()` to examine the type of the data.

# %%
type([1,2,3,4,5])
# Out:
# list

# %%
type((1,2,3,4))
# Out:
# tuple

# %%
type({'milk tea':40, 'coffee':80})
# Out:
# dict

# %%
type({1,2,3})
# Out:
# set
