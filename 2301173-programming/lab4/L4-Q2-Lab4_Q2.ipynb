# %% [markdown]
# ## Q2
# จงเขียนโปรแกรมที่รับตำแหน่ง (x,y) เริ่มต้นของหุ่นยนต์จากผู้ใช้ (x และ y เป็นจำนวนเต็ม) <br>
# แล้วอ่านลำดับของคำสั่งที่ให้หุ่นยนต์เดินไปทางซ้าย (L) ขวา (R) ขึ้นบน (U) ลงล่าง (D) ครั้งละ 1 หน่วย <br>
# จากไฟล์ **move\<n\>.txt** แล้วหาว่าเมื่อจบโปรแกรมหุ่นยนต์จะไปอยู่ที่ตำแหน่งใด โดยให้มีกำแพงที่เส้น **x=10, x=-10, y=10 และ y=-10**<br>
# ถ้าการเดินของหุ่นยนต์จะทำให้หุ่นยนต์ชนกำแพง หุ่นยนต์จะไม่เคลื่อนที่จากตำแหน่งเดิม เช่น
# เมื่อหุ่นยนต์อยู่ที่ (9,2) และได้คำสั่ง R หุ่นจะชนกำแพงที่เส้น x=10 ดังนั้นจะไม่ขยับตำแหน่ง
# **ผู้ใช้จะพิมพ์ตำแหน่งเริ่มต้นของหุ่นยนต์ให้อยู่ภายในกำแพงเท่านั้น**

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# ไฟล์ move3.txt: <br>
# L <br>
# L <br>
# D <br>
# R <br>
# R <br>
# R <br>
# R <br>
# ----
# Choose your movefile: **move3.txt** <br>
# Initial position : **9,-9** <br>
# Robot stops at 9,-9

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# ไฟล์ move3.txt:<br>
# L <br>
# L <br>
# D <br>
# R <br>
# R <br>
# R <br>
# R <br>
# ---
# Choose your movefile: **move3.txt** <br>
# Initial position : **8,4** <br>
# Robot stops at 9,3

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# ไฟล์ move4.txt: <br>
# L <br>
# L <br>
# X <br>
# U <br>
# D <br>
# Z <br>
# R <br>
# ----
# Choose your movefile: **move4.txt** <br>
# Initial position : **1,2** <br>
# Invalid command

# %%
import sys

# **x=10, x=-10, y=10 และ y=-10**
WALLS = {
    "X": [10, -10],
    "Y": [10, -10] 
}

def run():
    # Choose your movefile: **move2.txt** <br>
    # Initial position : **10,20** <br>
    # Invalid command
    filename = input("Choose your movefile:")
    pos = tuple([int(n) for n in input("Initial position :").split(",")])
    pos_list = ""
    print(pos, file=sys.stderr)
    with open(filename, "r") as f:
        pos_list = [l.strip() for l in f.readlines()]
    for d in pos_list:
        temp_pos = pos
        if d == "L":
            temp_pos = (pos[0] - 1, pos[1])
        elif d == "R":
            temp_pos = (pos[0] + 1, pos[1])
        elif d == "U":
            temp_pos = (pos[0], pos[1] + 1)
        elif d == "D":
            temp_pos = (pos[0], pos[1] - 1)
        else:
            print("Invalid command")
            return
        if temp_pos[0] in WALLS["X"] or temp_pos[1] in WALLS["Y"]:
            continue
        pos = temp_pos
    print(f"Robot stops at {pos[0]},{pos[1]}")

# %%
'''ตรวจสอบผลลัพธ์ของโปรแกรมด้วยการรันที่ cell นี้'''
# run()
# Out:
# 'ตรวจสอบผลลัพธ์ของโปรแกรมด้วยการรันที่ cell นี้'

# %%
'''ตรวจสอบผลการคำนวณ'''
from unittest.mock import patch
from io import StringIO
import math

def test(inputs,expected_output): 
    with patch('builtins.input', side_effect=inputs), patch('sys.stdout', new_callable=StringIO) as mock_stdout:
        run()
        assert mock_stdout.getvalue() == expected_output,mock_stdout.getvalue()
def test_easy_print(inputs,expected_output):
    with patch('builtins.input', side_effect=inputs), patch('sys.stdout', new_callable=StringIO) as mock_stdout:
        run()
        assert expected_output in mock_stdout.getvalue(), mock_stdout.getvalue()

# %%
'''ตรวจสอบการแสดงผลลัพธ์อย่างง่าย'''
test_easy_print(inputs=['move3.txt','9,-9'],expected_output='Robot')
print('ok')
# Out:
# ok
# (9, -9)

# %%
'''ตรวจสอบผลการคำนวณและการแสดงผลลัพธ์ให้เหมือนกับโจทย์ที่กำหนดให้'''
'''Robot can stop at position x,y'''
test(['move3.txt','9,-9'],'Robot stops at 9,-9\n') #ex
test(['move3.txt','8,4'],'Robot stops at 9,3\n') #ex
test(['move3.txt','9,5'],'Robot stops at 9,4\n') # ++
test(['move3.txt','-5,5'],'Robot stops at -3,4\n')  #-+
test(['move3.txt','-1,-1'],'Robot stops at 1,-2\n')  #--
print('ok')
# Out:
# ok
# (9, -9)
# (8, 4)
# (9, 5)
# (-5, 5)
# (-1, -1)

# %%
'''ตรวจสอบผลการคำนวณและการแสดงผลลัพธ์ให้เหมือนกับโจทย์ที่กำหนดให้'''
'''Invalid command'''
test(['move4.txt','5,5'],'Invalid command\n') #
test(['move4.txt','1,1'],'Invalid command\n') #
test(['move4.txt','1,2'],'Invalid command\n') #ex
print('ok')
# Out:
# (5, 5)
# ok
# (1, 1)
# (1, 2)

# %%
'''เทสลับ1'''
# Out:
# 'เทสลับ1'

# %%
'''เทสลับ2'''
# Out:
# 'เทสลับ2'
